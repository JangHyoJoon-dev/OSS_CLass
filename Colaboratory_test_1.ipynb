# %% [markdown]
# <a href="https://colab.research.google.com/github/JangHyoJoon-dev/OSS_CLass/blob/main/Colaboratory_test_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $ M_{c,o,i,j}

# %%
date_input = '2018-03-01'#@param { type : "date"}

# %%
import pandas as pd

pd.read_csv('/content/real_estate.csv', encoding = 'CP949')
# Out:
#                  시군구       번지      본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동    658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 1      서울특별시 강남구 개포동    658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202204
# 2      서울특별시 강남구 개포동    658-1   658.0   1.0  개포6차우성아파트1동~8동    79.97  202205
# 3      서울특별시 강남구 개포동     1282  1282.0   0.0       개포래미안포레스트   102.32  202204
# 4      서울특별시 강남구 개포동     1282  1282.0   0.0       개포래미안포레스트   136.06  202205
# ...              ...      ...     ...   ...             ...      ...     ...
# 13846  서울특별시 중랑구 중화동      450   450.0   0.0  한신아파트(103~109)    59.76  202207
# 13847  서울특별시 중랑구 중화동      450   450.0   0.0  한신아파트(103~109)    84.03  202207
# 13848  서울특별시 중랑구 중화동      450   450.0   0.0  한신아파트(103~109)    50.37  202302
# 13849  서울특별시 중랑구 중화동   274-51   274.0  51.0         한영(101)    84.69  202204
# 13850  서울특별시 중랑구 중화동  11월 07일    11.0   7.0     현대휴앤미(102동)    76.43  202204
#
# ...
